# %% [markdown]
# <a href="https://colab.research.google.com/github/rsaputranur-gif/pemograman-dasar/blob/main/4232511041rian%20saputra%20nur0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "rian saputra nur"
umur = 21
jurusan = "RPE"
semester = 3
matakuliah = 'pemerogram dasar'
status_lulus = False



print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# rian saputra nur
# 21
# RPE
# 3
# pemerogram dasar
# False
