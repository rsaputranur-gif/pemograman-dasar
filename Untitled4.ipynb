# %% [markdown]
# <a href="https://colab.research.google.com/github/rsaputranur-gif/pemograman-dasar/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# jawabn 1
tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"


print (tegangan, arus, jenis_sel)

# Jawaban Latihan 2
jumlah_pin = 8          # int
kapasitansi = 100.5     # float
sudah_terpasang = True  # bool
nama_komponen = "IC 555"# str

print(jumlah_pin, type(jumlah_pin))
print(kapasitansi, type(kapasitansi))
print(sudah_terpasang, type(sudah_terpasang))
print(nama_komponen, type(nama_komponen))

# Jawaban Latihan 3
nama_unit = "PLTS Nunukan"  # str
jumlah_panel = 240         # int
tegangan_keluaran = 48.5   # float
sedang_beroperasi = True   # bool

print(type(nama_unit))
print(type(jumlah_panel))
print(type(tegangan_keluaran))
print(type(sedang_beroperasi))

# Jawaban Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print("Pertama:", tegangan_harian[0])
print("Terakhir:", tegangan_harian[-1])

tegangan_harian.append(222.0)

print("Total data:", len(tegangan_harian))

# Jawaban Latihan 5
motor = {
    "nama": "Motor Induksi",
    "daya_kW": 15,
    "tegangan_V": 380,
    "rpm": 1450
}
print("RPM Awal:", motor["rpm"])
motor["rpm"] = 1500

print(motor)

pembangkit = [
    {"nama": "PLTU Unit 1", "kapasitas_MW": 100, "status": "Operasi"},
    {"nama": "PLTA Unit 2", "kapasitas_MW": 50, "status": "Pemeliharaan"},
    {"nama": "PLTD Unit 3", "kapasitas_MW": 25, "status": "Operasi"}
]

print("Nama unit kedua:", pembangkit[1]["nama"])

# 3. Ubah status salah satu unit (misal Unit 2)
pembangkit[1]["status"] = "Operasi"

# 4. Tambahkan satu unit baru ke list dengan append()
pembangkit.append({"nama": "PLTS Unit 4", "kapasitas_MW": 15, "status": "Standby"})

# 5. Cetak seluruh data
print("Data seluruh pembangkit:")
print(pembangkit)


--
# Out:
# 18 6 Monocrystalline
# 8 <class 'int'>
# 100.5 <class 'float'>
# True <class 'bool'>
# IC 555 <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# Pertama: 217.5
# Terakhir: 216.9
# Total data: 7
# RPM Awal: 1450
# {'nama': 'Motor Induksi', 'daya_kW': 15, 'tegangan_V': 380, 'rpm': 1500}
# Nama unit kedua: PLTA Unit 2
# Data seluruh pembangkit:
# [{'nama': 'PLTU Unit 1', 'kapasitas_MW': 100, 'status': 'Operasi'}, {'nama': 'PLTA Unit 2', 'kapasitas_MW': 50, 'status': 'Operasi'}, {'nama': 'PLTD Unit 3', 'kapasitas_MW': 25, 'status': 'Operasi'}, {'nama': 'PLTS Unit 4', 'kapasitas_MW': 15, 'status': 'Standby'}]
